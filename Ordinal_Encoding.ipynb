# %% [markdown]
# # Ordinal Encoding In Machine Learning

# %%
import pandas as pd
df = pd.DataFrame({"Size":["s","m","l","xl","s", "m", "l", "s","s","l","xl","m"]})
df.head(3)
# Out:
#   Size
# 0    s
# 1    m
# 2    l

# %%
ord_data = [["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=ord_data)
oe.fit(df[["Size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
oe.transform(df[["Size"]])
df['Size_en'] = oe.transform(df[["Size"]])

# %%
df.head(3)
# Out:
#   Size  Size_en
# 0    s      0.0
# 1    m      1.0
# 2    l      2.0

# %% [markdown]
# ## How to do the same thing using map function

# %%
ord_data1 = {'s':0,"m":1,"l":4,"xl":25}
df["Size_en_map"]= df['Size'].map(ord_data1)

# %%
df
# Out:
#    Size  Size_en  Size_en_map
# 0     s      0.0            0
# 1     m      1.0            1
# 2     l      2.0            4
# 3    xl      3.0           25
# 4     s      0.0            0
# 5     m      1.0            1
# 6     l      2.0            4
# 7     s      0.0            0
# 8     s      0.0            0
# 9     l      2.0            4
# 10   xl      3.0           25
# 11    m      1.0            1

# %% [markdown]
# #### How to see this thing in real word data

# %%
df = pd.read_csv('Diwali Sales Data.csv', encoding='latin1')
df.head(3)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders   Amount  \
# 0     Maharashtra   Western  Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central  Automobile             Auto       3  23924.0
#
#    Status  unnamed1
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN

# %%
# df['Occupation'].unique()
# Out:
# array(['Healthcare', 'Govt', 'Automobile', 'Construction',
#        'Food Processing', 'Lawyer', 'IT Sector', 'Media', 'Banking',
#        'Retail', 'Hospitality', 'Aviation', 'Agriculture', 'Textile',
#        'Chemical'], dtype=object)

# %%
df['Zone'].unique()
# Out:
# array(['Western', 'Southern', 'Central', 'Northern', 'Eastern'],
#       dtype=object)

# %%
en_ord_data = [["Northern","Southern","Central","Western","Eastern"]]

# %%
from sklearn.preprocessing import OrdinalEncoder
oen = OrdinalEncoder(categories=en_ord_data)
df['ordinal_encoding_zone'] = oen.fit_transform(df[['Zone']])

# %%
df['ordinal_encoding_zone'].head(3)
# Out:
# 0    3.0
# 1    1.0
# 2    2.0
# Name: ordinal_encoding_zone, dtype: float64
